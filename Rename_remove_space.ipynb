# %%
import pandas as pd
import glob

# %%
data_files = glob.glob("data\*")
files = glob.glob('data\*.txt')

# %%
files[0]
# Out:
# 'data\\005795f8-IMG_2149_126.txt'

# %%
def remove_space_rename(data_files):

    for i in range(len(data_files)):
        r = data_files[i].replace(" ","_")
        if( r != data_files[i]):
            print("renamed")
            os.rename(data_files[i],r)

# %%
def replace_labels(files):
    for i in range(len(files)):
        # Read in the file
        edit_this = str(files[i])
        with open(edit_this, 'r') as file :
          filedata = file.read()

        # Replace the target string
        try:
            if "-1" in filedata:
                print(str(files[i]) + " Changed")
            filedata = filedata.replace('-1', '0')
            
        except:
            continue

        # Write the file out again
        with open(edit_this, 'w') as file:
          file.write(filedata)

# %%
replace_labels(files)

# %%
remove_space_rename(data_files)
# Out:
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
# renamed
