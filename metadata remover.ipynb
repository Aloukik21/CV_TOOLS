# %%
from PIL import Image
import glob

# %%
path_read = glob.glob("data\*.jpg")
output = "/data_output"
file_name = []

# %%
path_read
# Out:
# ['data\\1593610921395.jpg',
#  'data\\1593610921416.jpg',
#  'data\\1593610921433.jpg',
#  'data\\1593610921435.jpg',
#  'data\\1593610921437.jpg',
#  'data\\1593610921460.jpg',
#  'data\\1593610921479.jpg',
#  'data\\1593610921481.jpg',
#  'data\\1593610921516.jpg',
#  'data\\1593610921521.jpg',
#  'data\\1593610921551.jpg',
#  'data\\1593610921553.jpg',
#  'data\\1593610921555.jpg',
#  'data\\1593610921560.jpg',
#  'data\\1593610921571.jpg',
#  'data\\1593610921588.jpg',
#  'data\\1593610921589.jpg',
#  'data\\1593610921590.jpg',
#  'data\\1593610921593.jpg',
#  'data\\1593610921610.jpg',
#  'data\\1593610921625.jpg',
#  'data\\1593610921643.jpg',
#  'data\\1593610921711.jpg',
#  'data\\1593610921769.jpg',
#  'data\\1593610921849.jpg',
#  'data\\1593610921850.jpg',
#  'data\\1593610921909.jpg',
#  'data\\1593610921910.jpg',
#  'data\\1593610921922.jpg',
#  'data\\1593610921946.jpg',
#  'data\\1593610921961.jpg',
#  'data\\1593610921974.jpg',
#  'data\\1593610921979.jpg',
# ...

# %%
path_read[0][5:]
# Out:
# '1593610921395.jpg'

# %%
for i in range(len(path_read)):
    
    filename = path_read[i][5:]
    
    image = Image.open(path_read[i])
    image.save("output/" + filename)
